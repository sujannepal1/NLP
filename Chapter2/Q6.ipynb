# %% [markdown]
# # Exercise 6: Simple Keyboard Prediction
#
# ## Objective
# Predict the most common next word.

# %%
corpus = [  
"I like NLP",
"I like Python",
"I like coffee",
"I love NLP"
]

# %% [markdown]
# • Build bi-gram counts.
# • Store next-word frequencies.
# • Display the top three predictions.

# %%
bi_gram_list = []
for value in corpus:
    words = value.split()
    bi_gram = bi_gram_list.extend(zip(words[:-1], words[1:]))

print(bi_gram_list)
# Out:
# [('I', 'like'), ('like', 'NLP'), ('I', 'like'), ('like', 'Python'), ('I', 'like'), ('like', 'coffee'), ('I', 'love'), ('love', 'NLP')]

# %%
from collections import Counter
#frequency of the individual bigrams
def get_count(val: list):
    freq = Counter(bi_gram_list).most_common()
    return freq

# %%
frequency = get_count(bi_gram_list)
# Out:
# Counter({('I', 'like'): 3, ('like', 'NLP'): 1, ('like', 'Python'): 1, ('like', 'coffee'): 1, ('I', 'love'): 1, ('love', 'NLP'): 1})

# %%
# def get_last_word_from_text(text):
#         return text.split()[-1]

# def predict_next_word(text: str):
#     last_word: str = get_last_word_from_text(text)
#     for bi_gram in bi_gram_list:
#           pass
